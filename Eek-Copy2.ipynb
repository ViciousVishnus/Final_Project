# %%
from scipy.interpolate import interp1d
from scipy.interpolate import splrep
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

try:
    from jupyterthemes import jtplot
    jtplot.style()
except ImportError:
    pass

import mygrad as mg
import numpy as np
from mygrad.nnet.activations import sigmoid

# %%
mic_avg = np.average(michael_arr[:][:],axis=1)
#vishnu_avg = np.average(vishnu_arr[:][:],axis=1)
zer = mic_avg
for val in range(len(vishnu_arr)):
    pix_mean = np.mean(mic_avg[val],axis=0)
    print(pix_mean.shape)
    pix_std = np.std(mic_avg[val],axis = 0)
    print(pix_std.shape)
    print(zer[0].shape)
    zer[val] = (zer[val]-pix_mean)/pix_std
mic_avg = zer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9ad697162d81> in <module>()
# ----> 1 mic_avg = np.average(michael_arr[:][:],axis=1)
#       2 #vishnu_avg = np.average(vishnu_arr[:][:],axis=1)
#       3 zer = mic_avg
#       4 for val in range(len(vishnu_arr)):
#       5     pix_mean = np.mean(mic_avg[val],axis=0)
#
# NameError: name 'michael_arr' is not defined

# %%
mic_avg,vishnu_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-73e226c8e00d> in <module>()
# ----> 1 mic_avg,vishnu_avg
#
# NameError: name 'mic_avg' is not defined

# %%
#mic_avg = np.average(michael_arr[:][:],axis=1)
vishnu_avg = np.average(vishnu_arr[:][:],axis=1)
zer = vishnu_avg
for val in range(len(vishnu_arr)):
    pix_mean = np.mean(vishnu_avg[val],axis=0)
    print(pix_mean.shape)
    pix_std = np.std(vishnu_avg[val],axis = 0)
    print(pix_std.shape)
    print(zer[0].shape)
    zer[val] = (zer[val]-pix_mean)/pix_std
vishnu_avg = zer
# Out:
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)
# (2,)
# (2,)
# (20, 2)

# %%
vishnu_arr = np.load("VishnuData.npy")
michael_arr = np.load("MichaelData.npy")
listy = [vishnu_arr,michael_arr]
print(listy)
val = np.array(michael_arr[0][8][:][:])
time = np.linspace(0,20,20)
fig,axy = plt.subplots()
#for value in range(len(vishnu_arr[0])):
    
axy.plot(np.interp(range(20),np.linspace(0,20,20),mic_avg[6][:,1]),color='#0082ff',alpha=0.2)
#for value in range(len(vishnu_arr[0])):
    
axy.plot(np.interp(range(20),range(20),vishnu_avg[6][:,1]),color='#696969',alpha=0.2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-614b291e2454> in <module>()
# ----> 1 vishnu_arr = np.load("VishnuData.npy")
#       2 michael_arr = np.load("MichaelData.npy")
#       3 listy = [vishnu_arr,michael_arr]
#       4 print(listy)
#       5 val = np.array(michael_arr[0][8][:][:])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     370     own_fid = False
#     371     if isinstance(file, basestring):
# --> 372         fid = open(file, "rb")
#     373         own_fid = True
#     374     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'VishnuData.npy'

# %%
x_vals = np.linspace(0,8*np.pi,1000)
y_vals = np.sin(x_vals)
len(y_vals)
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.cos(-x**2/9.0)
f = interp1d(x, y)
f2 = interp1d(x, y, kind='cubic')
f3 = splrep(x,y,k=1)
plt.plot(f2.x,f2.y)

# %%
def create_parameters(n):
    """ Parameters
        ----------
        n : int 
            The number of parameters to use in our function approximator for
            w, b, and v."""
    w = mg.Tensor(np.random.randn(1,n))
    b = mg.Tensor(np.random.randn(n))
    v = mg.Tensor(np.random.randn(n,1))
    return (w,b,v)
vishnu_arr
# Out:
# array([[[[ 84.62220544, 426.96081114],
#          [ 83.70695698, 427.57702726],
#          [ 83.64475065, 428.13547108],
#          ...,
#          [443.15234274, 429.55601859],
#          [446.34961033, 428.88686383],
#          [503.38104296, 415.74129391]],
#
#         [[ 73.08854818, 427.36871451],
#          [ 73.11205292, 427.63128167],
#          [ 73.39292693, 427.79626915],
#          ...,
#          [446.51399326, 427.46516776],
#          [446.67680836, 425.87988186],
#          [454.71952415, 421.11190069]],
#
#         [[ 76.25205132, 425.81400943],
#          [ 76.66816527, 425.48727608],
#          [ 77.06176519, 425.69095778],
#          ...,
#          [533.85014284, 416.70218945],
#          [534.98775268, 423.06088185],
#          [532.97877818, 423.59321427]],
#
#         ...,
#
#         [[ 76.13410696, 425.82857037],
#          [ 77.1728878 , 426.5537529 ],
#          [ 75.92270798, 426.23802519],
#          ...,
#          [476.66076881, 424.99388719],
#          [474.15117073, 425.69715738],
#          [480.20230985, 420.72349143]],
#
#         [[ 73.29569197, 422.33200502],
#          [ 72.08432269, 421.65356302],
#          [ 72.10542583, 422.31952596],
#          ...,
#          [377.11677265, 407.39974308],
#          [500.39673755, 423.20892143],
#          [543.69600272, 425.63934398]],
#
#         [[ 57.33293438, 422.43381882],
#          [ 57.72486997, 421.75168467],
#          [ 58.02774584, 421.24110878],
#          ...,
#          [363.71293813, 413.89780343],
#          [466.52182472, 409.00558805],
#          [550.14045   , 422.94352484]]],
#
#
#        [[[ 88.15879416, 333.36271501],
#          [ 89.80384922, 334.89793158],
#          [ 92.71318793, 338.83378351],
#          ...,
#          [455.68152571, 333.52796626],
#          [478.27728796, 336.14833474],
#          [543.3794508 , 334.96385622]],
#
#         [[ 72.35985947, 331.50362396],
#          [ 72.05315876, 332.74557078],
#          [ 74.92769253, 332.09503569],
#          ...,
#          [448.95241404, 334.44361472],
#          [451.94475587, 332.89897555],
#          [494.9326942 , 331.84257858]],
#
#         [[ 80.34802437, 333.74565327],
#          [ 81.67472959, 332.2324805 ],
#          [ 84.37498993, 333.92900896],
#          ...,
#          [505.06236887, 331.66255355],
#          [526.93131185, 333.86081743],
#          [546.41157329, 330.58702755]],
#
#         ...,
#
#         [[ 73.39759231, 336.90539598],
#          [ 74.11476111, 337.30914545],
#          [ 76.73213136, 334.53069854],
#          ...,
#          [478.74804664, 331.81774835],
#          [480.26101375, 334.36749101],
#          [518.01593709, 334.24047518]],
#
#         [[ 69.41844428, 333.86047208],
#          [ 69.27429652, 332.75149161],
#          [ 70.48901176, 333.58588302],
#          ...,
#          [432.59813356, 337.64113641],
#          [491.963767  , 330.41911936],
#          [532.96302056, 338.4090029 ]],
#
#         [[ 58.10799229, 331.39485097],
#          [ 57.55581737, 331.81706221],
#          [ 57.09886551, 331.56377825],
#          ...,
#          [414.8119688 , 333.03019762],
#          [497.96240306, 322.41286051],
#          [522.90006649, 338.28334713]]],
#
#
#        [[[111.66808772, 331.90553682],
#          [109.00943375, 333.14813268],
#          [118.92241168, 334.9493258 ],
#          ...,
#          [481.83317471, 328.84297609],
#          [498.34874022, 333.12060034],
#          [510.76207089, 328.00263357]],
#
#         [[ 96.12861013, 331.76482292],
#          [ 94.04901218, 332.10400322],
#          [ 91.11366594, 330.90420675],
#          ...,
#          [426.80890858, 327.99694347],
#          [487.82193303, 325.52590084],
#          [501.86195457, 324.71414071]],
#
#         [[101.51252353, 331.80473691],
#          [101.26553357, 331.1462819 ],
#          [ 98.71677756, 332.11696535],
#          ...,
#          [445.29456794, 333.50597501],
#          [487.47569323, 327.57101917],
#          [556.63016582, 323.39320189]],
#
#         ...,
#
#         [[ 98.05769157, 333.00280333],
#          [ 98.24775231, 333.8660326 ],
#          [101.76382267, 332.17417146],
#          ...,
#          [459.61858952, 326.29528379],
#          [512.27370262, 330.84018993],
#          [533.84800243, 330.81411314]],
#
#         [[ 98.40024221, 330.72909772],
#          [ 98.26028705, 329.8165493 ],
#          [ 99.34514731, 330.73240101],
#          ...,
#          [443.90516597, 335.6429801 ],
#          [443.77285957, 333.9932791 ],
#          [479.74856138, 334.9261663 ]],
#
#         [[ 81.77542281, 331.12749022],
#          [ 81.46091223, 331.77933347],
#          [ 82.3999238 , 330.98972166],
#          ...,
#          [436.39336267, 332.78541255],
#          [448.74652576, 325.65326607],
#          [467.34411007, 335.51407981]]],
#
#
#        ...,
#
#
#        [[[108.25642762, 193.45110464],
#          [108.60930973, 193.69376731],
#          [109.16068697, 196.40414166],
#          ...,
#          [437.92477322, 181.09113526],
#          [470.79564071, 182.36482668],
#          [508.93918926, 189.12883031]],
#
#         [[102.41505575, 198.62492776],
#          [102.27947378, 198.84896755],
#          [ 99.48384494, 200.04917884],
#          ...,
#          [425.71194601, 188.01255   ],
#          [441.89594698, 181.53883457],
#          [478.04732084, 186.0961448 ]],
#
#         [[ 90.16241717, 199.95087576],
#          [ 89.69825244, 197.27872205],
#          [ 98.37722886, 196.62046266],
#          ...,
#          [459.54977414, 187.70076063],
#          [495.03032994, 188.01424162],
#          [501.50615358, 178.72936928]],
#
#         ...,
#
#         [[108.17610201, 194.75399292],
#          [108.12894641, 194.15762711],
#          [107.62663698, 193.0922389 ],
#          ...,
#          [459.09928817, 190.17962146],
#          [478.0156014 , 182.34311152],
#          [521.48230052, 191.55346346]],
#
#         [[107.83813146, 199.4157443 ],
#          [107.65188941, 199.43585205],
#          [107.49417979, 198.9245863 ],
#          ...,
#          [428.22835951, 193.97366309],
#          [457.4979136 , 197.91720986],
#          [510.58337665, 200.29846025]],
#
#         [[ 94.58243465, 201.34187698],
#          [ 94.97746444, 201.42249155],
#          [ 95.65057659, 200.14611125],
#          ...,
#          [412.79563767, 194.27737939],
#          [462.07290125, 197.5274477 ],
#          [498.70922649, 203.43318266]]],
#
#
#        [[[132.39697099, 248.26536608],
#          [132.8739239 , 247.72986031],
#          [136.99820948, 248.07838392],
#          ...,
#          [465.42394137, 243.15304536],
#          [485.76739597, 244.41549751],
#          [518.30304861, 252.01654415]],
#
#         [[119.95867825, 253.03426552],
#          [120.46081972, 252.66786671],
#          [120.33237696, 250.07748938],
#          ...,
#          [438.15551305, 246.70266271],
#          [467.64033157, 243.79765053],
#          [499.20861125, 241.49583268]],
#
#         [[108.24001405, 251.07244796],
#          [107.94169315, 246.25450492],
#          [121.43547344, 249.22824574],
#          ...,
#          [480.76289225, 243.44308317],
#          [508.66890067, 243.06343633],
#          [545.09257102, 233.7202611 ]],
#
#         ...,
#
#         [[122.99927342, 250.22519445],
#          [122.61739755, 249.49946499],
#          [121.84751678, 249.15749812],
#          ...,
#          [469.2917037 , 244.74879527],
#          [497.68135691, 244.32022485],
#          [533.2527566 , 246.13316464]],
#
#         [[124.74401289, 247.50693178],
#          [124.36912897, 246.10079122],
#          [129.84552431, 246.97881508],
#          ...,
#          [443.91547494, 245.067783  ],
#          [498.88800371, 240.06957912],
#          [544.88816762, 241.2233839 ]],
#
#         [[103.07904005, 250.18378985],
#          [102.99594331, 250.12490809],
#          [107.35592592, 250.01391137],
#          ...,
#          [428.99118811, 247.2256639 ],
#          [496.33292985, 240.39595461],
#          [526.05456948, 247.50272965]]],
#
#
#        [[[115.83341452,  56.34520555],
#          [115.75366122,  56.02081513],
#          [116.96543622,  53.35200572],
#          ...,
#          [478.44895601,  47.4348321 ],
#          [512.69420695,  49.12511921],
#          [540.85844922,  49.58038092]],
#
#         [[ 94.47795892,  55.08657718],
#          [ 94.52279043,  54.79918957],
#          [ 95.46127462,  54.74266934],
#          ...,
#          [458.04834652,  52.4229182 ],
#          [489.22151136,  51.54358375],
#          [517.12814963,  52.65895659]],
#
#         [[ 94.18523002,  57.79719472],
#          [ 94.985291  ,  58.35045934],
#          [ 96.82985091,  57.36901069],
#          ...,
#          [485.30697405,  61.00664699],
#          [529.86519504,  55.37253523],
#          [569.56178379,  53.20449626]],
#
#         ...,
#
#         [[ 94.22202682,  55.58791685],
#          [ 94.33529139,  55.67235923],
#          [ 96.13449764,  55.11680222],
#          ...,
#          [491.09374189,  53.1239202 ],
#          [520.99865675,  51.08843178],
#          [549.41129696,  52.79089469]],
#
#         [[ 81.7449348 ,  56.83933163],
#          [ 81.42406058,  57.07856488],
#          [ 81.52786207,  55.84809732],
#          ...,
#          [445.56815815,  58.40384769],
#          [478.44956398,  59.46626019],
#          [528.11162829,  59.63815355]],
#
#         [[ 70.09385085,  59.57647306],
#          [ 70.11307716,  59.54485902],
#          [ 74.01340687,  58.94167876],
#          ...,
#          [439.54230309,  56.43369365],
#          [480.41156411,  59.17107141],
#          [521.41460371,  62.19207001]]]])

# %%
# STUDENT CODE
def grad_desent(tens,rate):
    w,b,v = tens
    if(w.grad is not None):
        w.data -= rate * w.grad
    if(b.grad is not None):
        b.data -= rate * b.grad
    if(v.grad is not None):
        v.data -= rate * v.grad

# %%
test_x = np.linspace(0,10,10)
test_y = sigmoid(test_x)
plt.plot(test_x,test_y)

# %%
def forward_pass(x,pars):
    """batch: (M,1) array of input
        pars: tuple with the weight(w), bias(b), and v
        -----------------------------------------------
        Returns: Predictions for the function (pred)"""
    w,b,v = pars 
    out_1 = sigmoid(mg.matmul(x, w) + b)
    pred = model_out = mg.matmul(out_1, v)
    return pred

# %%
def l1_loss(preds,ans):
    l_val = mg.sum(mg.abs(preds-ans))
   # print(l_val)
    row,col = preds.shape
    return l_val/row
dict_fingerprints = {}

# %%
def create_parameters(n):
    """ Parameters
        ----------
        n : int 
            The number of parameters to use in our function approximator for
            w, b, and v."""
    w = mg.Tensor(np.random.randn(1,n))
    b = mg.Tensor(np.random.randn(n))
    v = mg.Tensor(np.random.randn(n,1))
    return (w,b,v)
############################################################################################################################
def forward_pass(x,pars):
    """batch: (M,1) array of input
        pars: tuple with the weight(w), bias(b), and v
        -----------------------------------------------
        Returns: Predictions for the function (pred)"""
    w,b,v = pars 
    out_1 = sigmoid(mg.matmul(x, w) + b)
    pred = model_out = mg.matmul(out_1, v)
    return pred
############################################################################################################################
def l1_loss(preds,ans):
    l_val = mg.sum(mg.abs(preds-ans))
   # print(l_val)
    row,col = preds.shape
    return l_val/row
############################################################################################################################
def true_f(x):
    return np.interp(x,np.linspace(0,20,20),person_arr[body_part][:,xOry])
############################################################################################################################
def grad_desent(tens,rate):
    w,b,v = tens
    if(w.grad is not None):
        w.data -= rate * w.grad
    if(b.grad is not None):
        b.data -= rate * b.grad
    if(v.grad is not None):
        v.data -= rate * v.grad
############################################################################################################################
def training():
    lr = 0.1
    # We will train for 1000 epochs; you can change this if you'd like
    for epoch_cnt in range(90000):
        idxs = np.arange(len(train_data))  # -> array([0, 1, ..., 9999])
        # shuffles these indices; we will use this to draw random batches
        # from our training data
        np.random.shuffle(idxs)  

        for batch_cnt in range(0, len(train_data)//batch_size):
            batch_indices = idxs[batch_cnt*batch_size : (batch_cnt + 1)*batch_size]
            batch = train_data[batch_indices]  # random batch of our training data

            # compute the predictions for this batch: F(x; w, b, v)
            preds = forward_pass(batch,(w,b,v))
           # print(preds)
            # compute the true (a.k.a desired) values for this batch: f(x) 
            true = true_f(batch)
           # print(true)
            # compute the loss associated with our predictions
            loss = l1_loss(preds,true)
            # back-propagate through your computational graph through your loss
            # this will compute: dL/dw, dL/db, dL/dv
            loss.backward()
            # execute your gradient descent function, passing all of your model's
            # parameters (w, b, v), and the learning rate. This will update your
            # model's parameters based on the loss that was computed
            grad_desent((w,b,v),lr)
            # FOR THE LOVE OF ALL THAT IS GOOD: NULL YOUR GRADIENTS
            w.null_gradients()
            b.null_gradients()
            v.null_gradients()
    return (w,b,v)
            # this will plot add your loss value to the liveplot. Note that
            # `loss.item()` returns a float - we can't pass the plotter a 0D-Tensor
############################################################################################################################
############################################################################################################################
############################################################################################################################
############################################################################################################################
def train_func(name,person_arr,num_params):
    fingerprint_arr = np.zeros((9,2,3,num_params))
    from scipy.interpolate import interp1d
    import numpy as np
    import mygrad as mg
    import numpy as np
    from mygrad.nnet.activations import sigmoid
    person_avg = np.average(person_arr[:][:],axis=1)
    for body_part in range(len(person_avg)):
        for xORy in range(2):
            train_data = mg.linspace(0,19,20).reshape(20,1)
            w,b,v = create_parameters(num_params)
            batch_size = 10
            params = training()
            for val in range(3):
                fingerprint_arr[body_part,xORy,val] = params[val]
    dict_fingerprints[name] = fingerprint_arr
    return dict_fingerprints

# %%
a = np.zeros((9,2,3,10))
r = np.linspace(0,19,20)
dict_fingerprints = {}
from mynn.layers.dense import dense
from mynn.initializers.normal import normal
from mynn.optimizers.sgd import SGD
from mynn.losses.cross_entropy import softmax_cross_entropy
from mynn.activations.relu import relu
from mynn.initializers.he_normal import he_normal

# %%
class Model:
    def __init__(self):
        self.dense1 = dense(1, 20, weight_initializer=normal)
        self.dense2 = dense(20, 30, weight_initializer=normal)
        self.dense3 = dense(30, 20, weight_initializer=normal)
        self.dense4 = dense(20, 1, weight_initializer=normal)
        
        
        self.dense1.weight.data=np.load("dense1_eek.npy")
        self.dense2.weight.data=np.load("dense2_eek.npy")
        self.dense3.weight.data=np.load("dense3_eek.npy")
        self.dense4.weight.data=np.load("dense4_eek.npy")
    def __call__(self, x):
        ''' Forward data through the network.
     
     
        This allows us to conveniently initialize a model `m` and then send data through it
        to be classified by calling `m(x)`.
        
        Parameters
        ----------
        x : Union[numpy.ndarray, mygrad.Tensor], shape=(N, D)
            The data to forward through the network.
            
        Returns
        -------
        mygrad.Tensor, shape=(N, 1)
            The model outputs.
        '''
        
        #We pass our data through a dense layer, use the activation function relu and then pass it through our second dense layer
        return self.dense4(sigmoid(self.dense3(sigmoid(self.dense2(sigmoid(self.dense1(x)))))))
    
    def weights1(self):
        weights=self.dense1.weight.data
        return weights
    def weights2(self):
        weights=self.dense2.weight.data
        return weights
    def weights3(self):
        weights=self.dense3.weight.data
        return weights
    def weights4(self):
        weights=self.dense4.weight.data
        return weights
    @property
    def parameters(self):
        ''' A convenience function for getting all the parameters of our model. '''
        return self.dense1.parameters + self.dense2.parameters + self.dense3.parameters + self.dense4.parameters

# %%
from mynn.optimizers.adam import Adam
model = Model()
optim = Adam(model.parameters)

# %%
import liveplot
plotter, fig, ax = liveplot.create_plot(metrics=["loss"], refresh=2.5)
ax.set_ylim(bottom=0,top=1)
# Create the shape-(1000,1) training data
train_data = mg.linspace(0,19,20).reshape(20,1)
# Create your parameters using your function `create_parameters`; 
# start off with N=10 for the number of model parameters
# to use for defining F(x)
w,b,v = create_parameters(10)

# Set `batch_size = 25`: the number of predictions that we will make in each training step


# Define the function `true_f`, which should just accept `x` and return `np.cos(x)`
def true_f(x):
    return np.interp(x,np.linspace(0,19,20),vishnu_avg[8][:,1])
# Out:
# <img src="data:image/png;base64,..." width="639.9977690675827">

# %%
#STUDENT CODE
# running this code will train your model; you can run it consecutively,
# with different learning rates to continue training your model.

# STUDENT CODE
# Running this code will recreate your model, re-initializing all of its parameters
# Thus you must re-run this cell if you want to train your model from scratch again.

# Create the liveplot figure using the code snippet above
batch_size = 10
# (or any other function that you want to approximate later on)

# set your "learning rate": the scaling parameter in gradient descent
# We will train for 1000 epochs; you can change this if you'd like
for epoch_cnt in range(200000):
    idxs = np.arange(len(train_data))  # -> array([0, 1, ..., 9999])
    # shuffles these indices; we will use this to draw random batches
    # from our training data
    np.random.shuffle(idxs)  
    
    for batch_cnt in range(0, len(train_data)//batch_size):
        batch_indices = idxs[batch_cnt*batch_size : (batch_cnt + 1)*batch_size]
        batch = train_data[batch_indices]  # random batch of our training data
        
        # compute the predictions for this batch: F(x; w, b, v)
        #print(batch)
        preds = model(batch)
       # print(len(preds))
        # compute the true (a.k.a desired) values for this batch: f(x) 
    
        true = true_f(batch)
       # print(true)
        # compute the loss associated with our predictions
        loss = l1_loss(preds,true)
        
        # back-propagate through your computational graph through your loss
        # this will compute: dL/dw, dL/db, dL/dv
        loss.backward()
        # execute your gradient descent function, passing all of your model's
        # parameters (w, b, v), and the learning rate. This will update your
        # model's parameters based on the loss that was computed
        optim.step()
        weights1 = model.weights1()
        weights2 = model.weights2()
        weights3 = model.weights3()
        weights4 = model.weights4()
        # FOR THE LOVE OF ALL THAT IS GOOD: NULL YOUR GRADIENTS
        loss.null_gradients()
        # this will plot add your loss value to the liveplot. Note that
        # `loss.item()` returns a float - we can't pass the plotter a 0D-Tensor
        plotter.set_train_batch({"loss"  : loss.item()},
                               batch_size=batch_size)
    np.save("dense1_eek.npy",weights1)
    np.save("dense2_eek.npy",weights2)
    np.save("dense3_eek.npy",weights3)
    np.save("dense4_eek.npy",weights4)

# %%
a=np.load("dense1_eek.npy")
b=np.load("dense2_eek.npy")
c=np.load("dense3_eek.npy")
d=np.load("dense4_eek.npy")
vishnu_R_shoulder_y = []
vishnu_R_shoulder_y.append(a)
vishnu_R_shoulder_y.append(b)
vishnu_R_shoulder_y.append(c)
vishnu_R_shoulder_y.append(d)
np.save("vishnu_R_shoulder_y",vishnu_R_shoulder_y)

# %%
# Out:
# array([[-9.98946446e-01, -4.34043514e-01, -1.25469666e+00,
#          2.62735301e+00, -1.35882054e+00,  9.46242552e-01,
#          8.22752043e-02, -5.09575037e-01,  5.98664143e-01,
#         -1.11970256e+00,  7.04451354e-01,  2.68267042e+00,
#          1.41832421e+00, -1.93644871e+00,  4.12997170e-01,
#          3.81016843e-01, -1.11477750e-01, -2.58078330e-01,
#         -7.25434379e-01,  1.34249464e+00,  1.46622746e+00,
#         -1.57317783e-01,  9.36363230e-01, -2.60681602e+00,
#          6.83942380e-04,  3.15231960e-01,  2.44126124e-01,
#          1.91027623e+00,  1.06362479e+00,  8.41677645e-01],
#        [ 5.11575149e-01,  7.06852129e-01,  1.65946302e+00,
#         -2.81447856e-01,  3.71498948e+00, -8.95889884e-01,
#         -4.41426979e-01,  3.46521813e+00, -4.83258604e-01,
#          3.37926678e-01,  6.27678142e-01,  6.45458378e-01,
#         -9.53467888e-01,  2.27743770e+00,  1.32429400e+00,
#         -1.21602295e+00,  1.21509228e+00, -4.09284323e-02,
#          4.52343822e+00, -2.75457265e-01, -5.24118355e+00,
#         -1.77727021e+00, -9.10355007e-01,  8.90896073e-01,
#          2.20489721e+00, -1.82370169e+00,  1.17184449e+00,
#         -1.52194381e+00, -4.82026071e+00,  1.14829202e+00],
#        [-2.59495921e+00,  1.07419188e+00, -1.42004448e-01,
#          7.78026347e-01,  1.07126925e+00, -1.04284872e+00,
#          5.88933425e-01,  1.05649189e+00,  1.40725200e+00,
#         -5.28636088e-01,  9.29073176e-01,  6.25417029e-01,
#          7.93422856e-01,  2.57533430e-01, -2.18632162e+00,
#          1.28258928e+00,  1.56304308e+00, -5.12784164e-01],
#        [ 2.07938309e-01, -1.23769512e-01, -4.73456952e-01,
#          1.10861835e+00, -1.83048858e+00, -6.36115421e-01,
#         -8.05880565e-01, -1.51692489e+00,  1.31910409e+00,
#         -1.86048743e-01, -1.22643802e+00, -2.69242830e-01,
#         -1.65013320e-01, -2.01949450e+00, -8.52139300e-01,
#          1.73291824e-01, -7.83049144e-01,  1.26390580e-01,
#         -2.90296892e+00,  1.20161237e+00,  2.96857425e-01,
#          1.28054756e+00,  6.72972166e-01,  5.55767264e-01,
#         -1.77511683e+00,  1.57776475e+00, -6.82809880e-01,
#          2.25900154e-01,  3.93808069e+00,  8.80016265e-02],
#        [-9.09760277e-01, -1.90802369e-01,  1.84156341e+00,
#         -6.91093075e-01,  3.68902278e+00, -2.61835653e+00,
#          2.49251406e+00,  3.74313281e+00, -3.67413153e+00,
#          1.28908536e+00, -3.91580402e-01, -1.82476943e+00,
#         -3.99036296e+00,  1.80436543e+00,  1.07888081e+00,
#         -5.97366764e-01,  2.79431612e+00,  2.67464187e-01,
#          3.06850459e+00, -1.49751162e+00, -5.14088830e+00,
#         -3.14665190e+00, -3.77511037e-01,  9.15452549e-01,
#          4.13842096e+00, -2.36990799e+00,  1.87438340e+00,
#         -9.89648952e-01, -1.44861095e+00,  2.55989733e-01],
#        [-1.90242262e+00, -9.30942115e-01,  2.72068623e+00,
#         -1.19105211e+00,  4.25932195e+00, -8.57827043e-01,
#          2.22376304e+00,  4.96312184e-01, -1.76516425e+00,
#          1.33011744e+00,  1.53683886e+00, -4.54726944e+00,
#          6.36705226e-01,  3.47266816e+00,  1.60220057e+00,
#         -1.61393988e+00,  3.04328410e+00, -2.38488682e+00,
#          4.49191208e+00, -8.72533034e-02, -4.94378138e+00,
#         -2.30224512e-01, -2.02170115e-01,  1.02247958e+00,
#          1.10587632e+00, -1.88231101e+00,  1.33323120e+00,
#         -2.11888561e-01, -4.38342821e+00,  2.07292006e-01]])

# %%
fig,ax = plt.subplots()
ax.plot(model(np.linspace(0,19,20).reshape(20,1)))
ax.plot(np.interp(range(20),np.linspace(0,19,20),vishnu_avg[8][:,1]))
#ax.plot(vishnu_avg[6][:,1])
np.interp(range(20),np.linspace(0,20,20),vishnu_avg[6][:,0])
# Out:
# <img src="data:image/png;base64,..." width="639.9977690675827">
# array([-1.09866312, -1.09850946, -1.10088247, -1.10496949, -1.12715848,
#        -1.10025459, -0.88754907, -0.63475905, -0.48159988, -0.36327338,
#        -0.20933658, -0.00181705,  0.22940995,  0.43095128,  0.60908375,
#         0.78783182,  0.98814763,  1.19858898,  1.44225677,  1.65331125])

# %%
figy,axi = plt.subplots()
dicty = train_func("vishnu",vishnu_arr,10)
w = dicty["vishnu"][0,0,0]
b = dicty["vishnu"][0,0,1]
v = dicty["vishnu"][0,0,2]
axi.plot(forward_pass(train_data,(w,b,v)))
axi.plot(np.interp(range(20),np.linspace(0,20,20),vishnu_avg[6][:,1]))
#ax.plot(vishnu_avg[6][:,1])
np.interp(range(20),np.linspace(0,20,20),vishnu_avg[6][:,1])
